# %%
corpus="hello welcome to the world of nlp ,we are learning about tokenization .and how are we going to do it !"

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # for newer NLTK versions

from nltk.tokenize import word_tokenize

corpus = "I am learning NLP using NLTK."
tokenized_corpus = word_tokenize(corpus)

print(tokenized_corpus)
# Out:
# ['I', 'am', 'learning', 'NLP', 'using', 'NLTK', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.tokenize import PunktSentenceTokenizer
corpus = "Hello world! This is a test. Let's see how it works."
sentence_tokenizer = PunktSentenceTokenizer()
sentence_tokenizer.tokenize(corpus)
print(sentence_tokenizer)

# %%
from nltk.tokenize import TreebankWordTokenizer
corpus = "Hello world! This is a test. Let's see how it works."
word_tokenizer = TreebankWordTokenizer()
tokenized_corpus = word_tokenizer.tokenize(corpus)
print(tokenized_corpus)
# Out:
# ['Hello', 'world', '!', 'This', 'is', 'a', 'test.', 'Let', "'s", 'see', 'how', 'it', 'works', '.']

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(corpus)
print(sent_tokenize(corpus))
# Out:
# ['Hello world!', 'This is a test.', "Let's see how it works."]

# %% [markdown]
# text preprocessing stemming

# %%
words=["eat","eating","eaten","write","writing","programming","programmer","programmers"]

# %%
from nltk.stem import PorterStemmer
porter_stemmer = PorterStemmer()
for word in words:
 print(porter_stemmer.stem(word))
# Out:
# eat
# eat
# eaten
# write
# write
# program
# programm
# programm

# %%
from nltk.stem import RegexpStemmer
regexp_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)
for word in words:
    print(regexp_stemmer.stem(word))
# Out:
# eat
# eat
# eaten
# writ
# writ
# programm
# programmer
# programmer

# %%
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english')
for word in words:
    print(snowball_stemmer.stem(word))
# Out:
# eat
# eat
# eaten
# write
# write
# program
# programm
# programm

# %% [markdown]
# text preprocessing lemmatization using nltk

# %%
from nltk.stem import WordNetLemmatizer
lemmatization = WordNetLemmatizer()
nltk.download('wordnet')


print(lemmatization.lemmatize("programming", pos="v"))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# program

# %%
for word in words:
    print(lemmatization.lemmatize(word, pos="v"))
# Out:
# eat
# eat
# eat
# write
# write
# program
# programmer
# programmers

# %%
paragraph="""was a renowned Indian aerospace scientist and politician who served as the 11th President of India from 2002 to 2007. Widely celebrated as the "Missile Man of India," he played a vital role in advancing the nation’s ballistic missile and nuclear technology programs.Born in Rameswaram, Tamil Nadu, into a humble family, Dr. Kalam overcame early financial hardships through sheer determination and a deep passion for education. He graduated in aeronautical engineering from the Madras Institute of Technology and dedicated decades of his career to premier national institutions like the DRDO and ISRO. Under his scientific and administrative leadership, India successfully developed indigenous missiles like Agni and Prithvi.In 2002, he was elected as the President of India, where his approachable, warm, and grounded demeanor earned him the affectionate title of "People's President". Throughout his life, Dr. Kalam was a passionate educator who constantly inspired millions of young students to dream big, work hard, and contribute to society. For his exceptional contributions to science and public service, he was honored with India's highest civilian award, the Bharat Ratna"""

# %%
sentence=sent_tokenize(paragraph)
print(sentence)
# Out:
# ['was a renowned Indian aerospace scientist and politician who served as the 11th President of India from 2002 to 2007.', 'Widely celebrated as the "Missile Man of India," he played a vital role in advancing the nation’s ballistic missile and nuclear technology programs.Born in Rameswaram, Tamil Nadu, into a humble family, Dr. Kalam overcame early financial hardships through sheer determination and a deep passion for education.', 'He graduated in aeronautical engineering from the Madras Institute of Technology and dedicated decades of his career to premier national institutions like the DRDO and ISRO.', 'Under his scientific and administrative leadership, India successfully developed indigenous missiles like Agni and Prithvi.In 2002, he was elected as the President of India, where his approachable, warm, and grounded demeanor earned him the affectionate title of "People\'s President".', 'Throughout his life, Dr. Kalam was a passionate educator who constantly inspired millions of youn
# ...

# %%
type(sentence)
# Out:
# list

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    words = [stemmer.stem(word.lower()) for word in words if word.lower() not in set(stopwords.words('english'))]
    sentence[i]=' '.join(words)

# %%
sentence
# Out:
# ['renown indian aerospac scientist politician serv 11th presid india 2002 2007 .',
#  "wide celebr `` missil man india , '' play vital role advanc nation ’ ballist missil nuclear technolog programs.born rameswaram , tamil nadu , humbl famili , dr. kalam overcam earli financi hardship sheer determin deep passion educ .",
#  'graduat aeronaut engin madra institut technolog dedic decad career premier nation institut like drdo isro .',
#  "scientif administr leadership , india success develop indigen missil like agni prithvi.in 2002 , elect presid india , approach , warm , ground demeanor earn affection titl `` peopl 's presid '' .",
#  'throughout life , dr. kalam passion educ constantli inspir million young student dream big , work hard , contribut societi .',
#  "except contribut scienc public servic , honor india 's highest civilian award , bharat ratna"]

# %%
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english')
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    words = [snowball_stemmer.stem(word.lower()) for word in words if word.lower() not in set(stopwords.words('english'))]
    sentence[i]=' '.join(words)

# %%
sentence
# Out:
# ['renown indian aerospac scientist politician serv 11th presid india 2002 2007 .',
#  'wide celebr `` missil man india , `` play vital role advanc nation ’ ballist missil nuclear technolog programs.born rameswaram , tamil nadu , humbl famili , dr. kalam overcam ear financ hardship sheer determin deep passion educ .',
#  'graduat aeronaut engin madra institut technolog dedic decad career premier nation institut like drdo isro .',
#  "scientif administr leadership , india success develop indigen missil like agni prithvi.in 2002 , elect presid india , approach , warm , ground demeanor earn affect titl `` peopl 's presid `` .",
#  'throughout life , dr. kalam passion educ constant inspir million young student dream big , work hard , contribut societi .',
#  "except contribut scienc public servic , honor india 's highest civilian award , bharat ratna"]

# %%
from nltk.stem import WordNetLemmatizer
lemmatization = WordNetLemmatizer()
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    words = [lemmatization.lemmatize(word.lower(),pos='v') for word in words if word.lower() not in set(stopwords.words('english'))]
    sentence[i]=' '.join(words)
    sentence

# %%
sentence
# Out:
# ['renown indian aerospac scientist politician serv 11th presid india 2002 2007 .',
#  'wide celebr `` missil man india , `` play vital role advanc nation ’ ballist missil nuclear technolog programs.born rameswaram , tamil nadu , humbl famili , dr. kalam overcam ear financ hardship sheer determin deep passion educ .',
#  'graduat aeronaut engin madra institut technolog dedic decad career premier nation institut like drdo isro .',
#  "scientif administr leadership , india success develop indigen missil like agni prithvi.in 2002 , elect presid india , approach , warm , grind demeanor earn affect titl `` peopl 's presid `` .",
#  'throughout life , dr. kalam passion educ constant inspir million young student dream big , work hard , contribut societi .',
#  "except contribut scienc public servic , honor india 's highest civilian award , bharat ratna"]

# %%
paragraph
# Out:
# 'was a renowned Indian aerospace scientist and politician who served as the 11th President of India from 2002 to 2007. Widely celebrated as the "Missile Man of India," he played a vital role in advancing the nation’s ballistic missile and nuclear technology programs.Born in Rameswaram, Tamil Nadu, into a humble family, Dr. Kalam overcame early financial hardships through sheer determination and a deep passion for education. He graduated in aeronautical engineering from the Madras Institute of Technology and dedicated decades of his career to premier national institutions like the DRDO and ISRO. Under his scientific and administrative leadership, India successfully developed indigenous missiles like Agni and Prithvi.In 2002, he was elected as the President of India, where his approachable, warm, and grounded demeanor earned him the affectionate title of "People\'s President". Throughout his life, Dr. Kalam was a passionate educator who constantly inspired millions of young students to
# ...

# %%
sentences = sent_tokenize(paragraph)
print(sentences)
# Out:
# ['was a renowned Indian aerospace scientist and politician who served as the 11th President of India from 2002 to 2007.', 'Widely celebrated as the "Missile Man of India," he played a vital role in advancing the nation’s ballistic missile and nuclear technology programs.Born in Rameswaram, Tamil Nadu, into a humble family, Dr. Kalam overcame early financial hardships through sheer determination and a deep passion for education.', 'He graduated in aeronautical engineering from the Madras Institute of Technology and dedicated decades of his career to premier national institutions like the DRDO and ISRO.', 'Under his scientific and administrative leadership, India successfully developed indigenous missiles like Agni and Prithvi.In 2002, he was elected as the President of India, where his approachable, warm, and grounded demeanor earned him the affectionate title of "People\'s President".', 'Throughout his life, Dr. Kalam was a passionate educator who constantly inspired millions of youn
# ...

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
for i in range(len(sentence)):
    words=word_tokenize(sentence[i])
    [word for word in words if word not in set(stopwords.words('english'))]
    nltk.download('averaged_perceptron_tagger')
    nltk.download('averaged_perceptron_tagger_eng')

    for i in range(len(sentence)):
        words = word_tokenize(sentence[i])
        filtered_words = [word for word in words if word.lower() not in set(stopwords.words('english'))]
        pos_tags = nltk.pos_tag(filtered_words)
        print(pos_tags)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# ...

# %%
print(nltk.pos_tag("taj mahel  is beautiful".split()))
# Out:
# [('taj', 'NN'), ('mahel', 'NN'), ('is', 'VBZ'), ('beautiful', 'JJ')]

# %%
sentence=" hwllo welcome to world of nlp ,we are learning about tokenization .and how are we going to do it !"

# %%
words=word_tokenize(sentence)

# %%
tag_elements=(nltk.pos_tag(words))

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements).draw()
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   hwllo/JJ
#   welcome/NN
#   to/TO
#   world/NN
#   of/IN
#   nlp/NN
#   ,/,
#   we/PRP
#   are/VBP
#   learning/VBG
#   about/IN
#   tokenization/NN
#   .and/NNP
#   how/WRB
#   are/VBP
#   we/PRP
#   going/VBG
#   to/TO
#   do/VB
#   it/PRP
#   !/.)
