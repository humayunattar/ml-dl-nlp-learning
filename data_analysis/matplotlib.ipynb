# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,56,2,]
y=[21,12,3,1,22]
plt.plot(x,y)

# %%
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("mywish")
plt.plot(x,y)

# %%
# create a customized line plot
plt.plot(x,y,color="red",linestyle="--",marker="o",linewidth=3,markersize=9)
plt.grid(True)

# %%
# multiple plot
x=[1,2,3,4,5,6]
y1=[10,12,13,45,14,15]
y2=[20,21,31,37,34,36]

# %%
plt.figure(figsize=(9,6))
plt.subplot(2,2,1)
plt.plot(x,y1,color="blue")

# %%
plt.subplot(2,2,2)
plt.plot(x,y2,color="blue")

# %%
plt.subplot(2,2,1)
plt.plot(x,y1,color="blue")



plt.subplot(2,2,2)
plt.plot(x,y2,color="blue")

plt.subplot(2,2,3)
plt.plot(y2,y1,color="blue")


plt.subplot(2,2,4)
plt.plot(y1,y2,color="blue")

# %%
#barplot
category=["a","b","c","d"]
value=[12,25,34,45]

plt.bar(category,value,color="purple")
# Out:
# <BarContainer object of 4 artists>

# %%
#histrogram are used to represent the distribution of dataset
data=[10,15,20,25,30,35,40,45,50,55,60,65,70,70,15,20,20,15,20,20,70,40,45,45,15,35,35]
plt.hist(data,bin=10,color="red",edgecolor="black")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 #histrogram are used to represent the distribution of dataset
#       2 data=[10,15,20,25,30,35,40,45,50,55,60,65,70,70,15,20,20,15,20,20,70,40,45,45,15,35,35]
# ----> 3 plt.hist(data,bin=10,color="red",edgecolor="black")
#
# File c:\Users\Asus\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
# createing the scatter plot
x=[10,12,14,15,]
y=[45,2,15,13]
plt.scatter(x,y,marker="x")

# %%
#piecahrt
labels=["A","B","C","D"]
sizes=[30,20,40,10]

color=["green ","blue","red","yellow"]
explode=(0,0.2,0,0)
color=["green","blue","red","yellow"]
plt.pie(sizes,labels=labels,explode=explode,autopct="%1.1f%%",colors=color)
# Out:
# ([<matplotlib.patches.Wedge at 0x29f77d6dd10>,
# ...
#  [Text(0.6465637011386807, 0.8899187493079641, 'A'),
#   Text(-1.0517221461286828, 0.7641207544246379, 'B'),
#   Text(-0.3399188151951704, -1.046162128485022, 'C'),
#   Text(1.0461621838648125, -0.339918644753721, 'D')],
#  [Text(0.3526711097120076, 0.48541022689525304, '30.0%'),
#   Text(-0.6472136283868817, 0.47022815656900785, '20.0%'),
#   Text(-0.1854102628337293, -0.5706338882645574, '40.0%'),
#   Text(0.5706339184717159, -0.185410169865666, '10.0%')])

# %%
import pandas as pd
df=pd.read_csv("50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#plot profit by markeing spent
total_profit_by_spent=df.groupby("State")["Marketing Spend"].sum()
total_profit_by_spent
# Out:
# State
# California    3103195.80
# Florida       3957176.82
# New York      3490882.27
# Name: Marketing Spend, dtype: float64

# %%
total_profit_by_spent.plot(kind="bar",color="red")
# Out:
# <Axes: xlabel='State'>
