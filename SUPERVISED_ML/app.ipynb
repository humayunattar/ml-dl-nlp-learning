# %%
import random

# %%
print(random.randint(1,10))
# Out:
# 8

# %%
print(random.choice(['apple', 'banana', 'cherry']) )
# Out:
# apple

# %%
import os
print(os.getcwd())
print(os.mkdir("test.txt"))
# Out:
# c:\Users\Asus\Desktop\krishnaik\module1
# None

# %%
print(os.getcwd())
# Out:
# c:\Users\Asus\Desktop\krishnaik\module1

# %%
import shutil
shutil.copyfile(r"C:\Users\Asus\Desktop\krishnaik\module1\test.txt", r"C:\Users\Asus\Desktop\krishnaik\module1\main.txt")
# Out:
# 'C:\\Users\\Asus\\Desktop\\krishnaik\\module1\\main.txt'

# %%
import csv
with open ("example.csv",mode="w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["Alice",30,"New York"])
    writer.writerow(["Bob",25,"Los Angeles"])
with open ("example.csv",mode="r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '25', 'Los Angeles']

# %%
from datetime import datetime,timedelta
now=datetime.now()
yesterday=now-timedelta(days=1)
print("Current date and time:",now)
print("Yesterday's date and time:",yesterday)
# Out:
# Current date and time: 2026-04-06 03:27:28.195702
# Yesterday's date and time: 2026-04-05 03:27:28.195702

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1775426358.9428954
# 1775426360.944323

# %%
from math import *

# %%
print(sqrt(16))
print(ceil(4.2))
print(floor(4.8))
# Out:
# 4.0
# 5
# 4

# %%
print(pi)
print(e)
print(sin(pi/2))
# Out:
# 3.141592653589793
# 2.718281828459045
# 1.0
